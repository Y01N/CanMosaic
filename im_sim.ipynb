# %%
# !pip install lpips torch torchvision

# %%
image1_path = "output_canvas_optimized.png"
image2_path = "test-images/pride.png"

# %%
import cv2
import numpy as np
from skimage.metrics import structural_similarity as ssim

def compute_image_similarity(image_path1, image_path2):
    # Read the images
    img1 = cv2.imread(image_path1)
    img2 = cv2.imread(image_path2)

    # Ensure the images are the same size
    img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

    # Convert images to grayscale
    gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

    # Compute SSIM between the two images
    similarity_score, _ = ssim(gray1, gray2, full=True)

    return similarity_score

# Example usage
similarity = compute_image_similarity(image1_path, image2_path)
print(f"Similarity score: {similarity}")
# Out:
# Similarity score: 0.5270582339591687

# %%
import cv2
import numpy as np

def compute_image_similarity_mse(image_path1, image_path2):
    # Read and resize images
    img1 = cv2.imread(image_path1)
    img2 = cv2.imread(image_path2)
    img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

    # Convert to grayscale
    gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY).astype(np.float32)
    gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY).astype(np.float32)

    # Compute MSE
    mse = np.mean((gray1 - gray2) ** 2)
    return mse

# Example usage
mse_score = compute_image_similarity_mse(image1_path, image2_path)
print(f"MSE score: {mse_score}")
# Out:
# MSE score: 17552.828125

# %%
import cv2
import torch
import lpips
import numpy as np

def compute_image_similarity_lpips(image_path1, image_path2, net='alex'):
    # Load LPIPS model (AlexNet by default)
    loss_fn = lpips.LPIPS(net=net)

    # Read and resize images
    img1 = cv2.imread(image_path1)
    img2 = cv2.imread(image_path2)
    img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

    # Convert from BGR to RGB, scale to [0,1]
    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB) / 255.0
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB) / 255.0

    # Convert to torch tensor and normalize to [-1, 1]
    def preprocess(img):
        tensor = torch.from_numpy(img).permute(2, 0, 1).unsqueeze(0).float()
        return (tensor * 2) - 1  # scale to [-1, 1]

    t1 = preprocess(img1)
    t2 = preprocess(img2)

    # Compute LPIPS distance
    with torch.no_grad():
        distance = loss_fn(t1, t2).item()
    return distance

# Example usage
lpips_score = compute_image_similarity_lpips(image1_path, image2_path)
print(f"LPIPS perceptual distance: {lpips_score}")
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# C:\Users\Eoin\AppData\Roaming\Python\Python312\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Eoin\AppData\Roaming\Python\Python312\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: C:\Users\Eoin\AppData\Roaming\Python\Python312\site-packages\lpips\weights\v0.1\alex.pth
# C:\Users\Eoin\AppData\Roaming\Python\Python312\site-packages\lpips\lpips.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path, map_location='cpu'), strict=False)
# LPIPS perceptual distance: 0.7550743222236633

# %%
import cv2
import numpy as np
import torch
import lpips
import time
from skimage.metrics import structural_similarity as ssim

# ---- CONFIGURATION ----
image_path1 = "image1.jpg"  # Replace with your image path
image_path2 = "image2.jpg"  # Replace with your image path

# ---- LOAD IMAGES ----
def load_and_resize_images(path1, path2):
    img1 = cv2.imread(path1)
    img2 = cv2.imread(path2)
    img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))
    return img1, img2

# ---- MSE ----
def compute_mse(img1, img2):
    gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY).astype(np.float32)
    gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY).astype(np.float32)
    return np.mean((gray1 - gray2) ** 2)

# ---- SSIM ----
def compute_ssim(img1, img2):
    gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
    score, _ = ssim(gray1, gray2, full=True)
    return score

# ---- LPIPS ----
def compute_lpips(img1, img2, net='alex'):
    loss_fn = lpips.LPIPS(net=net)
    img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB) / 255.0
    img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB) / 255.0

    def preprocess(img):
        tensor = torch.from_numpy(img).permute(2, 0, 1).unsqueeze(0).float()
        return (tensor * 2) - 1  # Scale to [-1, 1]

    t1 = preprocess(img1)
    t2 = preprocess(img2)

    with torch.no_grad():
        distance = loss_fn(t1, t2).item()
    return distance

# ---- RUN COMPARISON ----
img1 = cv2.imread(image1_path)
img2 = cv2.imread(image2_path)
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

results = {}

start = time.time()
mse = compute_mse(img1, img2)
results["MSE"] = (mse, time.time() - start)

start = time.time()
ssim_score = compute_ssim(img1, img2)
results["SSIM"] = (ssim_score, time.time() - start)

start = time.time()
lpips_score = compute_lpips(img1, img2)
results["LPIPS"] = (lpips_score, time.time() - start)

# ---- DISPLAY RESULTS ----
print("\n📊 Image Similarity Comparison\n")
for metric, (score, duration) in results.items():
    print(f"{metric:5s}: Score = {score:.5f} | Time = {duration:.4f} sec")
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# C:\Users\Eoin\AppData\Roaming\Python\Python312\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\Eoin\AppData\Roaming\Python\Python312\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: C:\Users\Eoin\AppData\Roaming\Python\Python312\site-packages\lpips\weights\v0.1\alex.pth
# C:\Users\Eoin\AppData\Roaming\Python\Python312\site-packages\lpips\lpips.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(model_path, map_location='cpu'), strict=False)
# 📊 Image Similarity Comparison
#
# MSE  : Score = 31215.88672 | Time = 0.3758 sec
# SSIM : Score = 0.37515 | Time = 13.9455 sec
# LPIPS: Score = 0.75507 | Time = 68.9088 sec

# %%
import cv2
import numpy as np
from PIL import Image
import random
import os
import json


def compute_image_similarity_mse(pil_img1, pil_img2):
    img1 = np.array(pil_img1.convert('L')).astype(np.float32)
    img2 = np.array(pil_img2.convert('L')).astype(np.float32)
    mse = np.mean((img1 - img2) ** 2)
    return -mse  # lower MSE = better match → negate for "higher is better"


def calculate_coverage_percent(canvas):
    alpha_channel = np.array(canvas.split()[-1])  # extract alpha channel
    non_transparent_pixels = np.count_nonzero(alpha_channel)
    total_pixels = alpha_channel.size
    coverage = (non_transparent_pixels / total_pixels) * 100
    return coverage


def create_canvas_with_optimized_placement(image_folder, image_real_width, image_real_height, 
                                           canvas_real_width, canvas_real_height, comparison_image_path,
                                           num_images=10, num_placements=10, dpi=300,
                                           mse_weight=1.0, coverage_weight=0.5):
    # Create the canvas
    canvas_width = int(canvas_real_width * dpi)
    canvas_height = int(canvas_real_height * dpi)
    canvas = Image.new('RGBA', (canvas_width, canvas_height), color=(255, 255, 255, 0))

    # Load and resize comparison image
    comparison_image = Image.open(comparison_image_path).convert('RGB')
    comparison_image = comparison_image.resize((canvas_width, canvas_height), Image.LANCZOS)

    # Get image list
    image_files = [f for f in os.listdir(image_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
    if not image_files:
        print("No image files found.")
        return canvas

    # Load first image to get size
    first_image = Image.open(os.path.join(image_folder, image_files[0])).convert('RGBA')
    scale_x = (image_real_width * dpi) / first_image.width
    scale_y = (image_real_height * dpi) / first_image.height
    scale = min(scale_x, scale_y)
    new_width = int(first_image.width * scale)
    new_height = int(first_image.height * scale)

    placements = []  # Store metadata for each placed can

    for i in range(num_images):
        best_score = -np.inf
        best_canvas = None
        best_metrics = None
        best_metadata = None

        for _ in range(num_placements):
            temp_canvas = canvas.copy()

            # Random can
            img_filename = random.choice(image_files)
            img_path = os.path.join(image_folder, img_filename)
            img = Image.open(img_path).convert('RGBA').resize((new_width, new_height), Image.LANCZOS)
            rotation_angle = random.uniform(0, 360)
            img_rotated = img.rotate(rotation_angle, expand=True, resample=Image.BICUBIC)

            # Bounding box + random paste position
            bbox = img_rotated.getbbox()
            rotated_width = bbox[2] - bbox[0]
            rotated_height = bbox[3] - bbox[1]
            max_x = canvas_width - rotated_width
            max_y = canvas_height - rotated_height
            paste_x = random.randint(0, max(0, max_x))
            paste_y = random.randint(0, max(0, max_y))

            # Paste can onto canvas
            temp_canvas.paste(img_rotated, (paste_x, paste_y), img_rotated)

            # Compute similarity + coverage
            mse_score = compute_image_similarity_mse(temp_canvas, comparison_image)
            coverage_score = calculate_coverage_percent(temp_canvas)

            # Weighted score
            combined_score = (mse_weight * mse_score) + (coverage_weight * coverage_score)

            if combined_score > best_score:
                best_score = combined_score
                best_canvas = temp_canvas
                best_metrics = (mse_score, coverage_score)
                best_metadata = {
                    "step": i + 1,
                    "filename": img_filename,
                    "translation": [paste_x, paste_y],
                    "rotation": rotation_angle,
                    "mse_score": float(mse_score),
                    "coverage": float(coverage_score)
                }

        # Finalize best placement for this step
        canvas = best_canvas
        placements.append(best_metadata)

        print(f"Image {i+1}/{num_images}: MSE = {-best_metrics[0]:.2f}, Coverage = {best_metrics[1]:.2f}%, Combined Score = {best_score:.2f}")
        # canvas.save(f"temp/output_canvas_step_{i+1}.png", format="PNG")

    # Save all placement data to JSON
    with open("placement_data.json", "w") as f:
        json.dump(placements, f, indent=2)

    return canvas

# %%
image_folder = "test-cans/8.16x4.83"  # Replace with your folder path
image_real_width = 8.16  # inches
image_real_height = 4.83  # inches
canvas_real_width = 50  # inches
canvas_real_height = 61  # inches
comparison_image_path = "test-images/mac.png"  # Path to the comparison image
num_images = 250  # Number of images to paste
num_placements = 100  # Number of random placements to try for each image
dpi = 30
mse_weight=1.0
coverage_weight=1.0

canvas = create_canvas_with_optimized_placement(image_folder, image_real_width, image_real_height, 
                                                canvas_real_width, canvas_real_height, comparison_image_path,
                                                num_images, num_placements,dpi, mse_weight, coverage_weight)
canvas.save("output_canvas_optimized.png", format="PNG")
print("Canvas created with optimized image placement and saved as output_canvas_optimized.png")
# Out:
# Image 1/250: MSE = 16472.30, Coverage = 0.86%, Combined Score = -16471.44
# Image 2/250: MSE = 16265.20, Coverage = 1.72%, Combined Score = -16263.47
# Image 3/250: MSE = 16090.50, Coverage = 2.59%, Combined Score = -16087.92
# Image 4/250: MSE = 15902.25, Coverage = 3.45%, Combined Score = -15898.80
# Image 5/250: MSE = 15751.52, Coverage = 4.28%, Combined Score = -15747.24
# Image 6/250: MSE = 15576.42, Coverage = 5.14%, Combined Score = -15571.29
# Image 7/250: MSE = 15425.60, Coverage = 6.00%, Combined Score = -15419.59
# Image 8/250: MSE = 15228.64, Coverage = 6.86%, Combined Score = -15221.78
# Image 9/250: MSE = 15048.17, Coverage = 7.73%, Combined Score = -15040.44
# Image 10/250: MSE = 14867.51, Coverage = 8.43%, Combined Score = -14859.08
# Image 11/250: MSE = 14694.69, Coverage = 9.29%, Combined Score = -14685.39
# Image 12/250: MSE = 14519.46, Coverage = 10.10%, Combined Score = -14509.37
# Image 13/250: MSE = 14370.25, Coverage = 10.96%, Combined Score = -14359.29
# Image 14/250: MSE = 14223.31, Coverage = 11.75%, Combined Score = -14211.56
# Image 15/250: MSE = 14068.71, Coverage = 12.61%, Combined Score = -14056.10
# Image 16/250: MSE = 13950.29, Coverage = 13.47%, Combined Score = -13936.82
# Image 17/250: MSE = 13787.92, Coverage = 14.34%, Combined Score = -13773.58
# Image 18/250: MSE = 13660.23, Coverage = 15.20%, Combined Score = -13645.04
# Image 19/250: MSE = 13496.94, Coverage = 16.06%, Combined Score = -13480.88
# Image 20/250: MSE = 13363.36, Coverage = 16.92%, Combined Score = -13346.44
# Image 21/250: MSE = 13235.73, Coverage = 17.78%, Combined Score = -13217.95
# Image 22/250: MSE = 13097.77, Coverage = 18.65%, Combined Score = -13079.12
# Image 23/250: MSE = 12950.13, Coverage = 19.47%, Combined Score = -12930.66
# Image 24/250: MSE = 12813.17, Coverage = 20.33%, Combined Score = -12792.84
# Image 25/250: MSE = 12690.69, Coverage = 21.20%, Combined Score = -12669.50
# Image 26/250: MSE = 12582.12, Coverage = 22.06%, Combined Score = -12560.07
# Image 27/250: MSE = 12472.80, Coverage = 22.89%, Combined Score = -12449.91
# Image 28/250: MSE = 12351.09, Coverage = 23.75%, Combined Score = -12327.34
# Image 29/250: MSE = 12223.22, Coverage = 24.37%, Combined Score = -12198.84
# Image 30/250: MSE = 12063.84, Coverage = 25.24%, Combined Score = -12038.61
# Image 31/250: MSE = 11954.88, Coverage = 26.10%, Combined Score = -11928.78
# Image 32/250: MSE = 11830.48, Coverage = 26.96%, Combined Score = -11803.52
# Image 33/250: MSE = 11722.00, Coverage = 27.72%, Combined Score = -11694.27
# Image 34/250: MSE = 11605.74, Coverage = 28.56%, Combined Score = -11577.18
# Image 35/250: MSE = 11506.62, Coverage = 29.37%, Combined Score = -11477.25
# Image 36/250: MSE = 11408.63, Coverage = 30.00%, Combined Score = -11378.63
# Image 37/250: MSE = 11295.66, Coverage = 30.53%, Combined Score = -11265.13
# Image 38/250: MSE = 11169.25, Coverage = 31.32%, Combined Score = -11137.93
# Image 39/250: MSE = 11060.04, Coverage = 32.18%, Combined Score = -11027.87
# Image 40/250: MSE = 10963.34, Coverage = 32.97%, Combined Score = -10930.37
# Image 41/250: MSE = 10841.79, Coverage = 33.83%, Combined Score = -10807.96
# Image 42/250: MSE = 10709.98, Coverage = 34.68%, Combined Score = -10675.30
# Image 43/250: MSE = 10593.30, Coverage = 35.11%, Combined Score = -10558.19
# Image 44/250: MSE = 10492.37, Coverage = 35.97%, Combined Score = -10456.39
# Image 45/250: MSE = 10389.89, Coverage = 36.79%, Combined Score = -10353.11
# Image 46/250: MSE = 10297.18, Coverage = 37.65%, Combined Score = -10259.53
# Image 47/250: MSE = 10201.27, Coverage = 38.49%, Combined Score = -10162.78
# Image 48/250: MSE = 10107.29, Coverage = 39.34%, Combined Score = -10067.95
# Image 49/250: MSE = 10023.29, Coverage = 39.78%, Combined Score = -9983.51
# Image 50/250: MSE = 9911.03, Coverage = 40.28%, Combined Score = -9870.74
# Image 51/250: MSE = 9830.21, Coverage = 40.87%, Combined Score = -9789.35
# Image 52/250: MSE = 9726.04, Coverage = 41.70%, Combined Score = -9684.35
# Image 53/250: MSE = 9641.96, Coverage = 42.49%, Combined Score = -9599.47
# Image 54/250: MSE = 9559.41, Coverage = 42.92%, Combined Score = -9516.49
# Image 55/250: MSE = 9485.08, Coverage = 43.61%, Combined Score = -9441.48
# Image 56/250: MSE = 9408.20, Coverage = 44.05%, Combined Score = -9364.15
# Image 57/250: MSE = 9317.68, Coverage = 44.89%, Combined Score = -9272.79
# Image 58/250: MSE = 9230.52, Coverage = 45.70%, Combined Score = -9184.82
# Image 59/250: MSE = 9132.82, Coverage = 46.21%, Combined Score = -9086.61
# Image 60/250: MSE = 9044.60, Coverage = 46.97%, Combined Score = -8997.63
# Image 61/250: MSE = 8966.47, Coverage = 47.73%, Combined Score = -8918.73
# Image 62/250: MSE = 8899.97, Coverage = 48.13%, Combined Score = -8851.85
# Image 63/250: MSE = 8821.06, Coverage = 48.97%, Combined Score = -8772.09
# Image 64/250: MSE = 8734.93, Coverage = 49.29%, Combined Score = -8685.64
# Image 65/250: MSE = 8677.53, Coverage = 49.87%, Combined Score = -8627.66
# Image 66/250: MSE = 8597.78, Coverage = 50.58%, Combined Score = -8547.21
# Image 67/250: MSE = 8524.83, Coverage = 51.13%, Combined Score = -8473.70
# Image 68/250: MSE = 8428.04, Coverage = 51.99%, Combined Score = -8376.05
# Image 69/250: MSE = 8331.49, Coverage = 52.72%, Combined Score = -8278.77
# Image 70/250: MSE = 8255.75, Coverage = 53.22%, Combined Score = -8202.53
# Image 71/250: MSE = 8181.75, Coverage = 53.67%, Combined Score = -8128.08
# Image 72/250: MSE = 8126.47, Coverage = 54.53%, Combined Score = -8071.94
# Image 73/250: MSE = 8050.83, Coverage = 55.10%, Combined Score = -7995.73
# Image 74/250: MSE = 7974.98, Coverage = 55.41%, Combined Score = -7919.57
# Image 75/250: MSE = 7914.23, Coverage = 56.07%, Combined Score = -7858.17
# Image 76/250: MSE = 7856.46, Coverage = 56.70%, Combined Score = -7799.75
# Image 77/250: MSE = 7803.20, Coverage = 56.98%, Combined Score = -7746.22
# Image 78/250: MSE = 7749.17, Coverage = 57.33%, Combined Score = -7691.84
# Image 79/250: MSE = 7674.92, Coverage = 57.95%, Combined Score = -7616.97
# Image 80/250: MSE = 7620.15, Coverage = 58.70%, Combined Score = -7561.46
# Image 81/250: MSE = 7560.75, Coverage = 59.23%, Combined Score = -7501.52
# Image 82/250: MSE = 7502.53, Coverage = 59.76%, Combined Score = -7442.77
# Image 83/250: MSE = 7440.34, Coverage = 60.44%, Combined Score = -7379.89
# Image 84/250: MSE = 7385.85, Coverage = 61.16%, Combined Score = -7324.69
# Image 85/250: MSE = 7329.47, Coverage = 61.59%, Combined Score = -7267.88
# Image 86/250: MSE = 7285.53, Coverage = 62.10%, Combined Score = -7223.43
# Image 87/250: MSE = 7233.23, Coverage = 62.57%, Combined Score = -7170.66
# Image 88/250: MSE = 7185.04, Coverage = 63.31%, Combined Score = -7121.73
# Image 89/250: MSE = 7136.72, Coverage = 63.73%, Combined Score = -7072.98
# Image 90/250: MSE = 7089.44, Coverage = 64.59%, Combined Score = -7024.85
# Image 91/250: MSE = 7035.72, Coverage = 64.85%, Combined Score = -6970.87
# Image 92/250: MSE = 6992.47, Coverage = 65.24%, Combined Score = -6927.23
# Image 93/250: MSE = 6943.87, Coverage = 65.75%, Combined Score = -6878.12
# Image 94/250: MSE = 6902.66, Coverage = 66.08%, Combined Score = -6836.58
# Image 95/250: MSE = 6857.75, Coverage = 66.22%, Combined Score = -6791.53
# Image 96/250: MSE = 6792.74, Coverage = 66.94%, Combined Score = -6725.80
# Image 97/250: MSE = 6741.74, Coverage = 67.53%, Combined Score = -6674.21
# Image 98/250: MSE = 6691.68, Coverage = 68.23%, Combined Score = -6623.45
# Image 99/250: MSE = 6660.12, Coverage = 68.62%, Combined Score = -6591.51
# Image 100/250: MSE = 6597.91, Coverage = 68.96%, Combined Score = -6528.95
# Image 101/250: MSE = 6569.34, Coverage = 69.30%, Combined Score = -6500.04
# Image 102/250: MSE = 6507.27, Coverage = 69.91%, Combined Score = -6437.36
# Image 103/250: MSE = 6470.10, Coverage = 70.73%, Combined Score = -6399.37
# Image 104/250: MSE = 6441.36, Coverage = 71.26%, Combined Score = -6370.10
# Image 105/250: MSE = 6395.51, Coverage = 71.44%, Combined Score = -6324.07
# Image 106/250: MSE = 6356.46, Coverage = 71.96%, Combined Score = -6284.50
# Image 107/250: MSE = 6322.83, Coverage = 72.39%, Combined Score = -6250.44
# Image 108/250: MSE = 6286.89, Coverage = 72.95%, Combined Score = -6213.94
# Image 109/250: MSE = 6257.46, Coverage = 73.28%, Combined Score = -6184.18
# Image 110/250: MSE = 6234.72, Coverage = 74.02%, Combined Score = -6160.70
# Image 111/250: MSE = 6202.24, Coverage = 74.21%, Combined Score = -6128.04
# Image 112/250: MSE = 6172.69, Coverage = 74.91%, Combined Score = -6097.78
# Image 113/250: MSE = 6142.35, Coverage = 75.12%, Combined Score = -6067.23
# Image 114/250: MSE = 6103.85, Coverage = 75.49%, Combined Score = -6028.36
# Image 115/250: MSE = 6072.21, Coverage = 76.07%, Combined Score = -5996.14
# Image 116/250: MSE = 6037.30, Coverage = 76.29%, Combined Score = -5961.00
# Image 117/250: MSE = 5997.19, Coverage = 76.54%, Combined Score = -5920.64
# Image 118/250: MSE = 5965.58, Coverage = 76.74%, Combined Score = -5888.84
# Image 119/250: MSE = 5942.49, Coverage = 77.08%, Combined Score = -5865.41
# Image 120/250: MSE = 5900.46, Coverage = 77.27%, Combined Score = -5823.18
# Image 121/250: MSE = 5859.47, Coverage = 77.45%, Combined Score = -5782.02
# Image 122/250: MSE = 5829.15, Coverage = 78.15%, Combined Score = -5751.01
# Image 123/250: MSE = 5802.08, Coverage = 78.52%, Combined Score = -5723.56
# Image 124/250: MSE = 5761.26, Coverage = 78.70%, Combined Score = -5682.56
# Image 125/250: MSE = 5735.92, Coverage = 79.05%, Combined Score = -5656.87
# Image 126/250: MSE = 5714.30, Coverage = 79.06%, Combined Score = -5635.25
# Image 127/250: MSE = 5690.28, Coverage = 79.36%, Combined Score = -5610.92
# Image 128/250: MSE = 5663.35, Coverage = 79.53%, Combined Score = -5583.82
# Image 129/250: MSE = 5640.29, Coverage = 79.66%, Combined Score = -5560.63
# Image 130/250: MSE = 5610.07, Coverage = 79.97%, Combined Score = -5530.10
# Image 131/250: MSE = 5587.50, Coverage = 80.11%, Combined Score = -5507.39
# Image 132/250: MSE = 5565.01, Coverage = 80.11%, Combined Score = -5484.90
# Image 133/250: MSE = 5543.83, Coverage = 80.14%, Combined Score = -5463.70
# Image 134/250: MSE = 5519.03, Coverage = 80.25%, Combined Score = -5438.77
# Image 135/250: MSE = 5491.95, Coverage = 80.35%, Combined Score = -5411.60
# Image 136/250: MSE = 5474.71, Coverage = 80.43%, Combined Score = -5394.28
# Image 137/250: MSE = 5446.97, Coverage = 80.53%, Combined Score = -5366.44
# Image 138/250: MSE = 5427.55, Coverage = 80.63%, Combined Score = -5346.93
# Image 139/250: MSE = 5406.54, Coverage = 80.77%, Combined Score = -5325.77
# Image 140/250: MSE = 5391.83, Coverage = 80.92%, Combined Score = -5310.91
# Image 141/250: MSE = 5372.44, Coverage = 81.11%, Combined Score = -5291.33
# Image 142/250: MSE = 5357.36, Coverage = 81.39%, Combined Score = -5275.97
# Image 143/250: MSE = 5341.01, Coverage = 81.53%, Combined Score = -5259.49
# Image 144/250: MSE = 5319.65, Coverage = 81.74%, Combined Score = -5237.91
# Image 145/250: MSE = 5293.01, Coverage = 82.57%, Combined Score = -5210.45
# Image 146/250: MSE = 5275.54, Coverage = 82.72%, Combined Score = -5192.82
# Image 147/250: MSE = 5248.69, Coverage = 82.94%, Combined Score = -5165.74
# Image 148/250: MSE = 5235.12, Coverage = 82.97%, Combined Score = -5152.15
# Image 149/250: MSE = 5215.90, Coverage = 82.99%, Combined Score = -5132.91
# Image 150/250: MSE = 5195.17, Coverage = 83.11%, Combined Score = -5112.07
# Image 151/250: MSE = 5178.53, Coverage = 83.30%, Combined Score = -5095.23
# Image 152/250: MSE = 5156.59, Coverage = 83.48%, Combined Score = -5073.11
# Image 153/250: MSE = 5146.11, Coverage = 83.52%, Combined Score = -5062.58
# Image 154/250: MSE = 5125.59, Coverage = 83.78%, Combined Score = -5041.81
# Image 155/250: MSE = 5109.37, Coverage = 84.02%, Combined Score = -5025.35
# Image 156/250: MSE = 5083.82, Coverage = 84.17%, Combined Score = -4999.65
# Image 157/250: MSE = 5063.25, Coverage = 84.25%, Combined Score = -4979.00
# Image 158/250: MSE = 5044.19, Coverage = 84.39%, Combined Score = -4959.80
# Image 159/250: MSE = 5019.96, Coverage = 84.50%, Combined Score = -4935.46
# Image 160/250: MSE = 4984.85, Coverage = 84.87%, Combined Score = -4899.98
# Image 161/250: MSE = 4959.58, Coverage = 85.22%, Combined Score = -4874.36
# Image 162/250: MSE = 4945.88, Coverage = 85.24%, Combined Score = -4860.64
# Image 163/250: MSE = 4923.11, Coverage = 85.35%, Combined Score = -4837.76
# Image 164/250: MSE = 4899.94, Coverage = 85.76%, Combined Score = -4814.18
# Image 165/250: MSE = 4879.37, Coverage = 85.84%, Combined Score = -4793.53
# Image 166/250: MSE = 4853.22, Coverage = 86.07%, Combined Score = -4767.15
# Image 167/250: MSE = 4823.75, Coverage = 86.24%, Combined Score = -4737.51
# Image 168/250: MSE = 4804.80, Coverage = 86.31%, Combined Score = -4718.49
# Image 169/250: MSE = 4795.25, Coverage = 86.37%, Combined Score = -4708.88
# Image 170/250: MSE = 4763.60, Coverage = 86.80%, Combined Score = -4676.80
# Image 171/250: MSE = 4750.66, Coverage = 86.94%, Combined Score = -4663.73
# Image 172/250: MSE = 4721.43, Coverage = 87.52%, Combined Score = -4633.91
# Image 173/250: MSE = 4706.57, Coverage = 87.59%, Combined Score = -4618.97
# Image 174/250: MSE = 4690.14, Coverage = 87.69%, Combined Score = -4602.45
# Image 175/250: MSE = 4675.43, Coverage = 87.91%, Combined Score = -4587.52
# Image 176/250: MSE = 4660.75, Coverage = 87.97%, Combined Score = -4572.78
# Image 177/250: MSE = 4642.94, Coverage = 88.24%, Combined Score = -4554.70
# Image 178/250: MSE = 4628.84, Coverage = 88.37%, Combined Score = -4540.47
# Image 179/250: MSE = 4617.81, Coverage = 88.38%, Combined Score = -4529.44
# Image 180/250: MSE = 4608.34, Coverage = 88.63%, Combined Score = -4519.71
# Image 181/250: MSE = 4595.46, Coverage = 88.64%, Combined Score = -4506.82
# Image 182/250: MSE = 4585.92, Coverage = 88.88%, Combined Score = -4497.04
# Image 183/250: MSE = 4571.94, Coverage = 89.04%, Combined Score = -4482.90
# Image 184/250: MSE = 4565.51, Coverage = 89.23%, Combined Score = -4476.28
# Image 185/250: MSE = 4555.98, Coverage = 89.31%, Combined Score = -4466.66
# Image 186/250: MSE = 4550.23, Coverage = 89.31%, Combined Score = -4460.92
# Image 187/250: MSE = 4535.20, Coverage = 89.45%, Combined Score = -4445.75
# Image 188/250: MSE = 4521.23, Coverage = 89.76%, Combined Score = -4431.46
# Image 189/250: MSE = 4505.45, Coverage = 89.80%, Combined Score = -4415.66
# Image 190/250: MSE = 4492.49, Coverage = 89.81%, Combined Score = -4402.68
# Image 191/250: MSE = 4483.62, Coverage = 89.97%, Combined Score = -4393.65
# Image 192/250: MSE = 4471.73, Coverage = 90.02%, Combined Score = -4381.71
# Image 193/250: MSE = 4461.71, Coverage = 90.03%, Combined Score = -4371.68
# Image 194/250: MSE = 4449.11, Coverage = 90.08%, Combined Score = -4359.02
# Image 195/250: MSE = 4431.96, Coverage = 90.11%, Combined Score = -4341.86
# Image 196/250: MSE = 4415.65, Coverage = 90.38%, Combined Score = -4325.27
# Image 197/250: MSE = 4406.31, Coverage = 90.40%, Combined Score = -4315.91
# Image 198/250: MSE = 4389.63, Coverage = 90.41%, Combined Score = -4299.22
# Image 199/250: MSE = 4375.55, Coverage = 90.43%, Combined Score = -4285.12
# Image 200/250: MSE = 4365.82, Coverage = 90.47%, Combined Score = -4275.36
# Image 201/250: MSE = 4357.07, Coverage = 90.64%, Combined Score = -4266.43
# Image 202/250: MSE = 4339.37, Coverage = 90.74%, Combined Score = -4248.63
# Image 203/250: MSE = 4321.11, Coverage = 90.74%, Combined Score = -4230.37
# Image 204/250: MSE = 4309.99, Coverage = 90.99%, Combined Score = -4219.01
# Image 205/250: MSE = 4291.00, Coverage = 91.05%, Combined Score = -4199.95
# Image 206/250: MSE = 4278.50, Coverage = 91.07%, Combined Score = -4187.43
# Image 207/250: MSE = 4263.01, Coverage = 91.08%, Combined Score = -4171.93
# Image 208/250: MSE = 4252.71, Coverage = 91.17%, Combined Score = -4161.54
# Image 209/250: MSE = 4241.74, Coverage = 91.20%, Combined Score = -4150.53
# Image 210/250: MSE = 4220.52, Coverage = 91.23%, Combined Score = -4129.29
# Image 211/250: MSE = 4209.22, Coverage = 91.36%, Combined Score = -4117.86
# Image 212/250: MSE = 4198.16, Coverage = 91.40%, Combined Score = -4106.76
# Image 213/250: MSE = 4183.08, Coverage = 91.46%, Combined Score = -4091.62
# Image 214/250: MSE = 4174.10, Coverage = 91.46%, Combined Score = -4082.64
# Image 215/250: MSE = 4165.87, Coverage = 91.49%, Combined Score = -4074.38
# Image 216/250: MSE = 4157.72, Coverage = 91.51%, Combined Score = -4066.21
# Image 217/250: MSE = 4149.72, Coverage = 91.64%, Combined Score = -4058.08
# Image 218/250: MSE = 4140.26, Coverage = 91.67%, Combined Score = -4048.59
# Image 219/250: MSE = 4132.00, Coverage = 91.74%, Combined Score = -4040.26
# Image 220/250: MSE = 4116.58, Coverage = 91.82%, Combined Score = -4024.76
# Image 221/250: MSE = 4105.11, Coverage = 91.83%, Combined Score = -4013.28
# Image 222/250: MSE = 4094.29, Coverage = 91.90%, Combined Score = -4002.39
# Image 223/250: MSE = 4088.48, Coverage = 91.90%, Combined Score = -3996.58
# Image 224/250: MSE = 4081.07, Coverage = 91.90%, Combined Score = -3989.17
# Image 225/250: MSE = 4070.21, Coverage = 91.92%, Combined Score = -3978.29
# Image 226/250: MSE = 4055.53, Coverage = 92.06%, Combined Score = -3963.47
# Image 227/250: MSE = 4043.17, Coverage = 92.07%, Combined Score = -3951.10
# Image 228/250: MSE = 4031.70, Coverage = 92.15%, Combined Score = -3939.55
# Image 229/250: MSE = 4027.74, Coverage = 92.16%, Combined Score = -3935.58
# Image 230/250: MSE = 4021.60, Coverage = 92.27%, Combined Score = -3929.33
# Image 231/250: MSE = 4014.59, Coverage = 92.27%, Combined Score = -3922.32
# Image 232/250: MSE = 4002.32, Coverage = 92.59%, Combined Score = -3909.73
# Image 233/250: MSE = 3987.62, Coverage = 92.60%, Combined Score = -3895.02
# Image 234/250: MSE = 3979.24, Coverage = 92.65%, Combined Score = -3886.59
# Image 235/250: MSE = 3970.28, Coverage = 92.71%, Combined Score = -3877.57
# Image 236/250: MSE = 3958.96, Coverage = 92.72%, Combined Score = -3866.24
# Image 237/250: MSE = 3952.02, Coverage = 92.76%, Combined Score = -3859.27
# Image 238/250: MSE = 3943.29, Coverage = 92.78%, Combined Score = -3850.51
# Image 239/250: MSE = 3936.56, Coverage = 92.83%, Combined Score = -3843.73
# Image 240/250: MSE = 3932.20, Coverage = 92.84%, Combined Score = -3839.37
# Image 241/250: MSE = 3924.30, Coverage = 92.85%, Combined Score = -3831.46
# Image 242/250: MSE = 3918.04, Coverage = 92.88%, Combined Score = -3825.16
# Image 243/250: MSE = 3911.65, Coverage = 92.88%, Combined Score = -3818.77
# Image 244/250: MSE = 3897.05, Coverage = 92.88%, Combined Score = -3804.17
# Image 245/250: MSE = 3878.75, Coverage = 92.91%, Combined Score = -3785.83
# Image 246/250: MSE = 3872.47, Coverage = 93.01%, Combined Score = -3779.46
# Image 247/250: MSE = 3867.97, Coverage = 93.10%, Combined Score = -3774.87
# Image 248/250: MSE = 3861.69, Coverage = 93.15%, Combined Score = -3768.54
# Image 249/250: MSE = 3852.80, Coverage = 93.17%, Combined Score = -3759.63
# Image 250/250: MSE = 3847.97, Coverage = 93.21%, Combined Score = -3754.76
# Canvas created with optimized image placement and saved as output_canvas_optimized.png

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# --- CONFIGURATION ---
json_path = "placement_data.json"
comparison_image_path = "test-images/mac.png"  # Update path if needed

# Real-world sizes (in inches)
image_real_width = 8.16  # inches
image_real_height = 4.83  # inches
canvas_real_width = 61  # inches
canvas_real_height = 50  # inches
dpi = 30

# --- Derived pixel sizes ---
canvas_width = int(canvas_real_width * dpi)
canvas_height = int(canvas_real_height * dpi)
w_px = int(image_real_width * dpi)
h_px = int(image_real_height * dpi)

# --- Load data ---
with open(json_path, "r") as f:
    placements = json.load(f)

comparison_image = Image.open(comparison_image_path).convert("RGB")
comparison_image = comparison_image.resize((canvas_width, canvas_height), Image.LANCZOS)

# --- Plot ---
fig, ax = plt.subplots(figsize=(12, 12))
ax.imshow(comparison_image)

for place in placements:
    x, y = place["translation"]
    theta = np.radians(place["rotation"])

    # Create rectangle corners centered at (0,0)
    hw, hh = w_px / 2, h_px / 2
    corners = np.array([
        [-hw, -hh],
        [ hw, -hh],
        [ hw,  hh],
        [-hw,  hh],
        [-hw, -hh]  # close the rectangle
    ])

    # Rotate and translate
    R = np.array([
        [np.cos(theta), -np.sin(theta)],
        [np.sin(theta),  np.cos(theta)]
    ])
    rotated = corners @ R.T + np.array([x + hw, y + hh])
    ax.plot(rotated[:, 0], rotated[:, 1], color='red', linewidth=1.5)

ax.set_title("Can Placement Overlay (Inches + DPI)")
ax.axis("off")
plt.tight_layout()
plt.show()
